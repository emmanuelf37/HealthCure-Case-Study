# %% [markdown]
# --Content Header--
#
# 1
#
# 2
#
# 3
#
# 4
#
# 5

# %% [markdown]
# ## Import Libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os
import statistics
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)
path = r'C:\Users\13019\Documents\Emmanuel\Data Analysis\Data Immersion\6.x'
# Out:
# C:\Users\13019\AppData\Local\Temp\ipykernel_13200\2998350499.py:6: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Import Dataframes

# %%
df = pd.read_csv(os.path.join(path,'Provisional_COVID-19_Deaths_by_Sex_and_Age.csv'), index_col = False);

# %% [markdown]
# ## Finding Basic Statistics on Dataframe

# %%
df.shape
# Out:
# (132192, 14)

# %%
df.head()
# Out:
#   Start Date   End Date     Group  Year  Month          State        Sex  \
# 0  1/1/2020   7/15/2023  By Total NaN   NaN     United States  All Sexes
# 1  1/1/2020   7/15/2023  By Total NaN   NaN     United States  All Sexes
# 2  1/1/2020   7/15/2023  By Total NaN   NaN     United States  All Sexes
# 3  1/1/2020   7/15/2023  By Total NaN   NaN     United States  All Sexes
# 4  1/1/2020   7/15/2023  By Total NaN   NaN     United States  All Sexes
#
#       Age Group  COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 0  All Ages      1137802.0        11735452.0    1132068.0
# 1  Under 1 year  509.0            69507.0       1010.0
# 2  0-17 years    1668.0           124091.0      2827.0
# 3  1-4 years     274.0            13473.0       646.0
# 4  5-14 years    504.0            20853.0       788.0
#
#    Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# 0  565790.0                       21992.0
# 1  93.0                           62.0
# 2  418.0                          503.0
# ...

# %%
df.describe(include = 'all')
# Out:
#        Start Date   End Date     Group           Year          Month  \
# count   132192     132192     132192    129438.000000  118422.000000
# unique  43         43         3        NaN            NaN
# top     1/1/2020   7/15/2023  By Month NaN            NaN
# freq    8262       8262       118422   NaN            NaN
# mean    NaN        NaN        NaN       2021.340426    6.093023
# std     NaN        NaN        NaN       1.057432       3.388188
# min     NaN        NaN        NaN       2020.000000    1.000000
# 25%     NaN        NaN        NaN       2020.000000    3.000000
# 50%     NaN        NaN        NaN       2021.000000    6.000000
# 75%     NaN        NaN        NaN       2022.000000    9.000000
# max     NaN        NaN        NaN       2023.000000    12.000000
#
#                 State        Sex Age Group  COVID-19 Deaths  Total Deaths  \
# count   132192         132192     132192    9.470700e+04     1.133510e+05
# ...

# %%
df['COVID-19 Deaths'].median()
# Out:
# 0.0

# %% [markdown]
# ## Fill in Blank cells with Median Value

# %%
df[['COVID-19 Deaths','Total Deaths','Pneumonia Deaths', 'Pneumonia and COVID-19 Deaths', 'Influenza Deaths', 'Pneumonia, Influenza, or COVID-19 Deaths']] = df[['COVID-19 Deaths','Total Deaths','Pneumonia Deaths', 'Pneumonia and COVID-19 Deaths', 'Influenza Deaths', 'Pneumonia, Influenza, or COVID-19 Deaths']].fillna(df[['COVID-19 Deaths','Total Deaths','Pneumonia Deaths', 'Pneumonia and COVID-19 Deaths', 'Influenza Deaths', 'Pneumonia, Influenza, or COVID-19 Deaths']].median())

# %% [markdown]
# ## Checking for Duplicates

# %%
df_dups = df;

# %%
df_dups = df_dups[df_dups.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Start Date, End Date, Group, Year, Month, State, Sex, Age Group, COVID-19 Deaths, Total Deaths, Pneumonia Deaths, Pneumonia and COVID-19 Deaths, Influenza Deaths, Pneumonia, Influenza, or COVID-19 Deaths]
# Index: []

# %%
## No Duplicates

# %% [markdown]
# ## Re-Checking Descriptive Statistics

# %%
df.describe()
# Out:
#                 Year          Month  COVID-19 Deaths  Total Deaths  \
# count  129438.000000  118422.000000  1.321920e+05     1.321920e+05
# mean   2021.340426    6.093023       2.314121e+02     2.445340e+03
# std    1.057432       3.388188       5.137507e+03     5.092185e+04
# min    2020.000000    1.000000       0.000000e+00     0.000000e+00
# 25%    2020.000000    3.000000       0.000000e+00     5.300000e+01
# 50%    2021.000000    6.000000       0.000000e+00     1.520000e+02
# 75%    2022.000000    9.000000       2.500000e+01     5.120000e+02
# max    2023.000000    12.000000      1.137802e+06     1.173545e+07
#
#        Pneumonia Deaths  Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# count  1.321920e+05      132192.000000                  132192.000000
# mean   2.360374e+02      115.671909                     4.158618
# std    5.021987e+03      2592.282582                    100.511722
# min    0.000000e+00      0.000000                       0.000000
# ...

# %% [markdown]
# ## Export Dataframe

# %%
df.to_csv(os.path.join(path,'Provisional_COVID-19_Deaths_by_Sex_and_Age_Updated.csv'))
